# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
from arcgis.gis import GIS
gis = GIS("home")

# %% [markdown]
# #### Now you are ready to start!

# %%
# import the User Manager class in gis module
from arcgis.gis import UserManager

# define UserManager
um = UserManager(gis)

# %%
# import the User Manager class in gis module
from arcgis.gis import GroupManager

# define UserManager
gm = GroupManager(gis)

# %%
# create a list of the groups that these users will be added too
myGroup = gis.groups.search('Team 2')
display (myGroup)
# Out:
# [<Group title:"Team 2" owner:ryan_cooper@eagle.co.nz>]

# %%
import random

# %%
userList = ['gxo']

# %%
for user in userList:
    
    username = user.upper() + '_USER2'
    password = 'gis12345'
    firstname = user.upper()
    lastname = 'USER2'
    email = 'eagleworkshop8@gmail.com'
    role = 'viewer'
    user = 'Viewer'
    icon = '/arcgis/home/Avatar{0}.png'.format(random.randint(1,20))
        
    newUser = um.create(username, password, firstname, lastname, email, role=role, user_type=user, credits=20, groups=[myGroup[0]], thumbnail=icon)
